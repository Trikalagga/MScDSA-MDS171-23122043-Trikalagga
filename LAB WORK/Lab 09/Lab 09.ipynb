# %%
# Lab 09
# TASK Lab 09
# Using the expenseTracker Class continue with the task:
# CREATE A CSV FIle for Expense/Income
# load the CSV File and populate the dictionary of the expenseTracker class
# find the total expense and income

# Additional Task
# Using the concept of menu driven programming,
# Show the menu options to add new transaction [expense/income]
# export the updated dictionary to the file.

class expensetracker:
    
    def __init__(self):
        self.transactions ={
            "expenses" : [],
            "income" : [],
            }
        
    def storetransaction(self,type,category,cost,description,date):
        transaction ={
              "Category": category,
              "Cost" : cost,
              "Description": description,
              "Date": date,
              }

        if  type == "expenses": 
            self.transactions['expenses'].append(transaction)

        else:
            self.transactions['income'].append(transaction)

        return True
        
    def view_transactions(self):
        print("INCOME")
        for expense in self.transactions['expenses']:
            print(expense)

        print("EXPENSES")
        for expense in self.transactions['expenses']:
            print(expense)  

    # total income
    def total_incomeexpense(self):
        print("Total income")
        total_income = 0
        for income in self.transactions['income']:
            total_income+=income["Cost"]
        print(total_income)

        print("Total Expense")
        total_expense = 0
        for expense in self.transactions['expenses']:
              total_expense += expense["Cost"]
        print(total_expense)


mytransactions = expensetracker()
with open("expensetracker(main).csv","r") as file:
        file.readline()
        for line in file.readlines():
            print(line.strip().split(",")) 
            # mytransactions.storetransaction()
# Out:
# ['income', 'Pocket money', '716', 'From parents', '01-09-2023']
# ['expense', 'violin', '2980', 'For Tai ji', '02-09-2023']
# ['expense', 'grocery', '4272', 'essential', '03-09-2023']
# ['income', 'offline part time job', '751', 'salary', '04-09-2023']
# ['expense', 'stationary', '2367', 'essential', '05-09-2023']
# ['income', 'online part time job', '510', 'salary', '06-09-2023']
# ['expense', 'donation', '572', 'charity', '07-09-2023']
# ['expense', 'Ganesh Puja', '2263', 'devotion', '08-09-2023']
# ['expense', 'lunch', '3922', 'food', '09-09-2023']
# ['expense', 'breakfast', '1845', 'food', '10-09-2023']
# ['expense', 'dinner', '710', 'food', '11-09-2023']
# ['expense', 'snacks', '3412', 'food', '12-09-2023']
# ['expense', 'camera', '3662', 'accessory', '13-09-2023']
# ['expense', 'bag', '733', 'accessory', '14-09-2023']
# ['expense', 'dance class', '2820', 'self work', '15-09-2023']
# ['expense', 'picnic', '3456', 'recreation', '16-09-2023']
# ['expense', 'dress', '4935', 'clothes', '17-09-2023']
# ['expense', 'saree', '1648', 'clothes', '18-09-2023']
# ['expense', 'grocery', '977', 'essential', '19-09-2023']
# ['income', 'stipend', '591', 'scholarship', '20-09-2023']
